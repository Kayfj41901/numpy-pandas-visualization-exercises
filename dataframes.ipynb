# %%
import pandas as pd

# %%
import numpy as np

# %%
from pydataset import data

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df)
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english > 70

# %%
print(df)
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df=df.sort_values(by='passing_english')
#duplicates seem to be handled by the database key-ascending

# %% [markdown]
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english','name'])
# Out:
#        name  math  english  reading  passing_english  grade_overall
# 11     Alan    92       62       72            False      75.333333
# 8    Albert    92       62       87            False      80.333333
# 7     Marie    93       63       90            False      82.000000
# 6    Thomas    82       64       81            False      75.666667
# 4       Ada    77       92       98             True      89.000000
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667
# 1      Jane    88       79       67             True      78.000000
# 5      John    79       76       93             True      82.666667
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 2     Suzie    94       74       95             True      87.666667

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by=['passing_english','english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df.sort_values(by=['english', 'passing_english'])
# Out:
#        name  math  english  reading  passing_english  grade_overall
# 8    Albert    92       62       87            False      80.333333
# 11     Alan    92       62       72            False      75.333333
# 7     Marie    93       63       90            False      82.000000
# 6    Thomas    82       64       81            False      75.666667
# 2     Suzie    94       74       95             True      87.666667
# 5      John    79       76       93             True      82.666667
# 1      Jane    88       79       67             True      78.000000
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 4       Ada    77       92       98             True      89.000000
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['grade_overall'] = round(df.math + df.english + df.reading)/3
df
# Out:
#        name  math  english  reading  passing_english  grade_overall   over_all
# 6    Thomas    82       64       81            False      75.666667  75.666667
# 7     Marie    93       63       90            False      82.000000  82.000000
# 8    Albert    92       62       87            False      80.333333  80.333333
# 11     Alan    92       62       72            False      75.333333  75.333333
# 0     Sally    62       85       80             True      75.666667  75.666667
# 1      Jane    88       79       67             True      78.000000  78.000000
# 2     Suzie    94       74       95             True      87.666667  87.666667
# 3     Billy    98       96       88             True      94.000000  94.000000
# 4       Ada    77       92       98             True      89.000000  89.000000
# 5      John    79       76       93             True      82.666667  82.666667
# 9   Richard    69       80       94             True      81.000000  81.000000
# ...

# %%
df.passing_english.sum()
#This returns all of the True's for passing english

# %%
df['over_all'] = df[["math", "english", "reading"]].mean(axis=1)
df.head()
#the axis=1 apply to each row instead of each column, the columns were specified earlier
# Out:
#       name  math  english  reading  passing_english  grade_overall   over_all
# 6   Thomas    82       64       81            False      75.666667  75.666667
# 7    Marie    93       63       90            False      82.000000  82.000000
# 8   Albert    92       62       87            False      80.333333  80.333333
# 11    Alan    92       62       72            False      75.333333  75.333333
# 0    Sally    62       85       80             True      75.666667  75.666667

# %% [markdown]
# MPG DATASET

# %%
mpg = data('mpg')
data('mpg')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# How many rows and columns are there?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Rename the cty column to city

# %%
mpg.rename(columns={'cty': 'city'},inplace=True)

# %% [markdown]
# Rename the hwy column to highway

# %%
mpg.rename(columns={'hwy': 'highway'},inplace=True)

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg['better_city'] = mpg.city > mpg.highway
print(mpg)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  better_city
# ...

# %%
mpg.sort_values(by='better_city')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 1           audi                   a4    1.8  1999    4    auto(l5)   f    18
# 149       nissan               maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan               maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan       pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# 152       nissan       pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 84          ford      f150 pickup 4wd    4.2  1999    6    auto(l4)   4    14
# 85          ford      f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford      f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 74         dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
# 234   volkswagen               passat    3.6  2008    6    auto(s6)   f    17
#
# ...

# %% [markdown]
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.highway - mpg.city)
print(mpg)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
print("The Volkswagen Jetta has the best highway mileage: 4 cyl, 1.9disp")
# Out:
# The Volkswagen Jetta has the best highway mileage: 4 cyl, 1.9disp

# %%
print("The Volkswagen Jetta has the worst highway mileage: 6 cyl, 2.8disp")
# Out:
# The Volkswagen Jetta has the worst highway mileage: 6 cyl, 2.8disp

# %%
mpg[mpg['class'] == 'compact'].sort_values(by="highway", ascending=False).head()
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen    jetta    1.9  1999    4  manual(m5)   f    33       44  d
# 197       toyota  corolla    1.8  2008    4  manual(m5)   f    28       37  r
# 196       toyota  corolla    1.8  1999    4  manual(m5)   f    26       35  r
# 198       toyota  corolla    1.8  2008    4    auto(l4)   f    26       35  r
# 195       toyota  corolla    1.8  1999    4    auto(l4)   f    24       33  r
#
#        class  better_city  mileage_difference
# 213  compact        False                  11
# 197  compact        False                   9
# 196  compact        False                   9
# 198  compact        False                   9
# 195  compact        False                   9

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway)/2
print(mpg)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which dodge car has the best average mileage? The worst?

# %%
mpg[(mpg.manufacturer == 'dodge')].sort_values(by='average_mileage').head()

# %%
print("The Dodge Ram 1500 pickup is the least fuel efficient Dodge automobile.")

# %%
mpg[(mpg.manufacturer == 'dodge')].sort_values(by='average_mileage').tail()

# %%
print("The Dodge Caravan is the most fuel efficient Dodge automobile.")

# %% [markdown]
# ### Mammals

# %% [markdown]
# mammals_dataset_here

# %%
mammals = data("Mammals")
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %% [markdown]
# How many rows and columns are there?

# %%
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# What are the data types?

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mammals.info
# Out:
# <bound method DataFrame.info of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals.describe
# Out:
# <bound method NDFrame.describe of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
mammals[mammals.speed == mammals.speed.max()].weight
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %% [markdown]
# What is the overall percentage of specials?

# %%
mammals.head()
# Out:
#    weight  speed  hoppers  specials
# 1  6000.0   35.0    False     False
# 2  4000.0   26.0    False     False
# 3  3000.0   25.0    False     False
# 4  1400.0   45.0    False     False
# 5   400.0   70.0    False     False

# %%
mammals.specials.mean()
# Out:
# 0.09345794392523364

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mammals[(mammals.hoppers == True) & (mammals.speed > mammals.speed.median())]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
a = len(mammals[(mammals.hoppers == True) & (mammals.speed > mammals.speed.median())])/ len(mammals)
a
# Out:
# 0.06542056074766354

# %% [markdown]
# ### ALL ROWS BELOW ARE EXTRA NOTES

# %%
mpg.info()

# %%
mpg[mpg.manufacturer== 'audi']
#give me a new data frame when you wrap it in brackets to show you just manufacturer audi

# %%
bm_df = mpg.manufacturer == 'audi'
#if you run just this it will run just Trues and Falses
bm_df

# %%
mpg[bm_df]

# %%
mpg[mpg['class'] == 'compact']

# %%
mpg[(mpg['class'] == 'compact') & (mpg.manufacturer == "audi")].sort_values(by='year',ascending=False)[['model', 'displ', 'year']]

# %%
chipotle.item_price.str.replace("$","").astype(float)
