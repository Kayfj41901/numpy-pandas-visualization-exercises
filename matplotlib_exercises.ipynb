# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import math

# %%
from random import randint

# %%
import random

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
# y=x**2−x+2
# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

# %% [markdown]
# Graph y = (x**2) - (x) + 2:

# %%
x = np.linspace(-10,10,10)
y = (x**2) - (x) + 2 
plt.plot(x, y, '-r', label='y=x**2-x+2')
plt.title('Graph of y=x**2-x+2')
plt.xlabel('X AXIS', color='#1C2833')
plt.ylabel('Y AXIS', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %% [markdown]
# y = sqrt(x)

# %%
#start, end, increment
x = np.linspace(0, 100, 100)
y = [math.sqrt(n) for n in x]

plt.annotate('origin', xy = (0,0), arrowprops= dict(facecolor = 'blue'))
plt.plot(x, y, 'r')
plt.title("Graph of y=x^0.5")
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# Graph y = x ** 3 Power:

# %%
x = np.linspace(-100, 100, 100)
y = x ** 3
fig = plt.figure()

plt.annotate('origin', xy = (0,0), arrowprops= dict(facecolor = 'blue'))
plt.plot(x, y, 'r')
plt.title("Graph of y=x**3")
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# Graph the line 2**x

# %%
x = np.linspace(-5, 5, 10)
y = 2 ** x
fig = plt.figure()

plt.annotate('origin', xy = (0,0), arrowprops= dict(facecolor = 'blue'))
plt.plot(x, y, 'r')
plt.title("Graph of y=2**x")
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
# 100 linearly spaced numbers 
x = np.linspace(-5, 5, 100)


# the function
y = (1)/(x+1)

#the setting the axes at the centre
fig = plt.figure()
plt.title("Graph of y = (1)/(x+1)")
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.annotate('origin', xy = (0,0), arrowprops= dict(facecolor = 'blue'))
# plot the function
plt.plot(x, y, 'r')

#show the plot 
plt.show()

# %% [markdown]
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x = np.linspace(0, 100, 10)
y1 = x ** .5
y2 = x ** 3 
y3 = [(2**i) for i in x]
y4 = [(1/(i+1)) for i in x]
y = [y1, y2, y3, y4]

plt.figure()
plt.style.use('default')

for i in range(len(y)): 
    plt.subplot(2,2,i+1)
    plt.plot(x,y[i])
    plt.grid()
    
    
plt.tight_layout()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.subplot
plot 
title 
label 
label 
grid 
xlim 
ylim

# %%
x = np.linspace(0, 10, 100)
y1 = x ** .5
y2 = x ** 3 
y3 = [(2**i) for i in x]
y4 = [(1/(i+1)) for i in x]
y = [y1, y2, y3, y4]
c = ['g', 'b', 'r', 'k']
ttl = ['y=x^1/2', 'y=x^3', 'y=2^x', 'y=(1)/(i+1)']
plt.figure()
plt.style.use('default')

for i in range(len(y)): 
    plt.subplot(2,2,i+1)
    plt.plot(x,y[i],c[i])
    plt.grid()
    plt.title(ttl[i])
    
    
plt.tight_layout()

# %%
plt.figure(figsize = (8, 6) 
          plt.plot(y1, c= , label = alpha= ))
