# %%
import pandas as pd

# %%
import numpy as np

# %%
from pydataset import data

# %%
from env import get_db_url

# %% [markdown]
# Three Exercises

# %% [markdown]
# Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)

# %% [markdown]
# Done

# %% [markdown]
# cd into your exercises folder for this module and run echo env.py >> .gitignore

# %% [markdown]
# Done

# %% [markdown]
# Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %% [markdown]
# Done

# %% [markdown]
# Use your function to obtain a connection to the employees database.

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50',get_db_url("employees"))
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# Once you have successfully run a query:
#     A.Intentionally make a typo in the database url. What kind of error message do you see?

# %%
print("could not parse url")
# Out:
# could not parse url

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
print("error: access denied 1044")
# Out:
# error: access denied 1044

# %% [markdown]
# Read the employees and titles tables into two separate DataFrames.

# %%
url = get_db_url("employees")
sql = """
SELECT * FROM employees 

"""
employees = pd.read_sql(sql, url)
employees.shape
# Out:
# (300024, 6)

# %%
sql = """
SELECT * FROM titles 
"""

titles = pd.read_sql(sql, url)
titles.head()

# %% [markdown]
# How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
titles.shape

# %%
employees.shape

# %% [markdown]
# Display the summary statistics for each DataFrame.

# %%
titles.describe(include='all')

# %%
employees.describe(include='all')

# %% [markdown]
# How many unique titles are in the titles DataFrame?

# %%
len(titles.title.unique())

# %% [markdown]
# What is the oldest date in the to_date column?

# %%
pd.read_sql("SELECT MAX(to_date) FROM titles", url)

# %%
titles.to_date.min()

# %% [markdown]
# What is the most recent date in the to_date column?

# %%
titles.to_date.max()

# %% [markdown]
# ## Exercise Two

# %% [markdown]
# Like the pandas series object, the pandas DataFrame object supports both position- and label-based indexing using the indexing operator []

# %% [markdown]
# ### Notes

# %%
df[['x', 'y']]

# %%
bools = df.x.str.startswith('T')
bools 
#will return True or False Statements

# %%
df[bools]
#this will return just the rows that would return 'true'

# %%
df.loc[row_indexer, column_indexer]

# %%
df.loc[bools, 'x': 'y']
#this will return the rows inside the x, y columns that meet the condition

# %%
df.iloc[:3]
#will return first three rows: 0,1,2

# %%
df.iloc[:3, 1:3]
#will return first three rows: 0,1,2 AND first three columns 0,1,2

# %% [markdown]
# ### Aggregating

# %%
df.reading.agg('min')
#returns the min reading score

# %%
df[['english', 'reading', 'math']] .agg(['mean', 'min', 'max'])
#returns the mean of english, the min of reading, and the max of math

# %% [markdown]
# ### Group By

# %%
df.groupby('classroom').math.max()
#to see top scores in two different classroom

# %%
df.groupby('classroom').math.agg(['min', 'mean', 'max'])
#this groups the rows by classrooms: first hour, second hour and shows min, mean, max

# %%
np.where(condition, this_where_True, this_where_False)
#where function allow us to base the new column values on whether the values in the existing column meet the condition

# %%
df['passing_math'] = np.where(df.math < 70, 'failing', 'passing')
df
#this creates a new column. the output is a column named passing math that returns "passing or failing"

# %%
grade_groups = df.groupby(['column1', 'column2']).reading.agg(['mean', 'count'])
grade_groups
#this will return four colums: column1, column2, mean column, and count column

# %%
#you can rename the columns like this: 
grade_groups.columns = ['avg_reading_grade', 'count_of_students']

# %% [markdown]
# ### Transform

# %%
df.assign(avg_math_score_by_classroom=df.groupby('classroom').math.transform('mean'))
#This takes the average math score per class and returns it back to the original dataframe that 
#housed all the students so that you can see in Sally's class the average math score is 82

# %%
df.groupby('classroom').reading.describe()
#this shows the count, mean, std, min, 25%, 50%, 75%, max

# %% [markdown]
# ## Exercises II

# %% [markdown]
# Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
print("The result of using a right join is receiving all keys from the right table and all the keys that overlap")
# Out:
# The result of using a right join is receiving all keys from the right table and all the keys that overlap

# %% [markdown]
# What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
print("The result of using an outer join is receiving all keys from both tables.")
# Out:
# The result of using an outer join is receiving all keys from both tables.

# %% [markdown]
# What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
print("While each table will have indices that you can use to merge, the corresponding values do not necessarily match. While it may be possible to force a join, the tables gathered will be useless.")
#error must pass right_on
# Out:
# While each table will have indices that you can use to merge, the corresponding values do not necessarily match. While it may be possible to force a join, the tables gathered will be useless.

# %% [markdown]
# Load the mpg dataset from PyDataset

# %%
mpg = data('mpg')
data('mpg')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %%
print('There are 234 rows and 11 columns')
# Out:
# There are 234 rows and 11 columns

# %% [markdown]
# Check out your column names and perform any cleanup you may want on them

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# How many different manufacturers are there?

# %%
mpg.manufacturer.unique().size
# Out:
# 15

# %% [markdown]
# How many different models are there?

# %%
mpg.model.unique().size
# Out:
# 38

# %% [markdown]
# Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.hwy - mpg.cty)

# %% [markdown]
# Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy)/(2)

# %% [markdown]
# Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.contains('auto')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage  is_automatic
# 1                  11             23.5          True
# 2                   8             25.0         False
# 3                  11             25.5         False
# 4                   9             25.5          True
# 5                  10             21.0          True

# %% [markdown]
# Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending=False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('trans').average_mileage.mean()
# Out:
# trans
# auto(av)      23.900000
# auto(l3)      24.000000
# auto(l4)      18.951807
# auto(l5)      17.717949
# auto(l6)      16.833333
# auto(s4)      22.166667
# auto(s5)      21.333333
# auto(s6)      21.281250
# manual(m5)    22.775862
# manual(m6)    20.552632
# Name: average_mileage, dtype: float64

# %% [markdown]
# ## Exercises III

# %% [markdown]
# Use your get_db_url function to help you explore the data from the chipotle database.

# %%
#I want to group by order id
#I want to add up the price i.e. sum 

cl = pd.read_sql('SELECT * FROM orders LIMIT 100',get_db_url("chipotle"))
cl
# Out:
#      id  order_id  quantity                              item_name  \
# 0     1         1         1           Chips and Fresh Tomato Salsa
# 1     2         1         1                                   Izze
# 2     3         1         1                       Nantucket Nectar
# 3     4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4     5         2         2                           Chicken Bowl
# 5     6         3         1                           Chicken Bowl
# 6     7         3         1                          Side of Chips
# 7     8         4         1                          Steak Burrito
# 8     9         4         1                       Steak Soft Tacos
# 9    10         5         1                          Steak Burrito
# 10   11         5         1                    Chips and Guacamole
# 11   12         6         1                   Chicken Crispy Tacos
# 12   13         6         1                     Chicken Soft Tacos
# 13   14         7         1                           Chicken Bowl
# 14   15         7         1                    Chips and Guacamole
# 15   16         8         1  Chips and Tomatillo-Green Chili Salsa
# 16   17         8         1                        Chicken Burrito
# 17   18         9         1                        Chicken Burrito
# 18   19         9         2                            Canned Soda
# 19   20        10         1                           Chicken Bowl
# 20   21        10         1                    Chips and Guacamole
# 21   22        11         1                       Barbacoa Burrito
# 22   23        11         1                       Nantucket Nectar
# 23   24        12         1                        Chicken Burrito
# 24   25        12         1                                   Izze
# 25   26        13         1           Chips and Fresh Tomato Salsa
# 26   27        13         1                           Chicken Bowl
# 27   28        14         1                       Carnitas Burrito
# 28   29        14         1                            Canned Soda
# 29   30        15         1                        Chicken Burrito
# 30   31        15         1  Chips and Tomatillo-Green Chili Salsa
# 31   32        16         1                          Steak Burrito
# 32   33        16         1                          Side of Chips
# 33   34        17         1                          Carnitas Bowl
# 34   35        17         1                          Bottled Water
# 35   36        18         1                     Chicken Soft Tacos
# 36   37        18         1                     Chicken Soft Tacos
# 37   38        18         1                    Chips and Guacamole
# 38   39        18         1  Chips and Tomatillo Green Chili Salsa
# 39   40        19         1                          Barbacoa Bowl
# 40   41        19         1                                  Chips
# 41   42        20         1                    Chips and Guacamole
# 42   43        20         1                           Chicken Bowl
# 43   44        20         1                          Steak Burrito
# 44   45        20         1                     Chicken Salad Bowl
# 45   46        21         1                        Chicken Burrito
# 46   47        21         1                          Steak Burrito
# 47   48        21         1                                   Izze
# 48   49        22         1                          Steak Burrito
# 49   50        22         1                    Chips and Guacamole
# 50   51        23         1                          Steak Burrito
# 51   52        23         2                            Canned Soda
# 52   53        24         1                        Chicken Burrito
# 53   54        24         1                            Canned Soda
# 54   55        25         1                             Steak Bowl
# 55   56        25         1           Chips and Fresh Tomato Salsa
# 56   57        26         1                    Barbacoa Soft Tacos
# 57   58        26         1                         Veggie Burrito
# 58   59        27         1                          Barbacoa Bowl
# 59   60        27         1                                  Chips
# 60   61        28         1                    Chips and Guacamole
# 61   62        28         1                       Steak Soft Tacos
# 62   63        28         1                            Veggie Bowl
# 63   64        28         1                        Chicken Burrito
# 64   65        29         1                          Steak Burrito
# 65   66        29         1                       Steak Soft Tacos
# 66   67        30         1                                   Izze
# 67   68        30         1                          Steak Burrito
# 68   69        30         1                        Chicken Burrito
# 69   70        31         1                          Steak Burrito
# 70   71        31         1                          Side of Chips
# 71   72        32         1                          Steak Burrito
# 72   73        32         1                    Chips and Guacamole
# 73   74        33         1                        Chicken Burrito
# 74   75        33         1                    Chips and Guacamole
# 75   76        34         1                     Chicken Soft Tacos
# 76   77        34         1                           Chicken Bowl
# 77   78        34         1                                  Chips
# 78   79        34         1                           Chicken Bowl
# 79   80        35         1                     Chicken Soft Tacos
# 80   81        35         1                                  Chips
# 81   82        36         1                       Barbacoa Burrito
# 82   83        36         1                        Chicken Burrito
# 83   84        37         1                        Chicken Burrito
# 84   85        37         1                       Steak Soft Tacos
# 85   86        38         1                            Veggie Bowl
# 86   87        38         1                             Steak Bowl
# 87   88        38         1                          Bottled Water
# 88   89        39         1                       Carnitas Burrito
# 89   90        39         1           Chips and Fresh Tomato Salsa
# 90   91        40         1                             Steak Bowl
# 91   92        40         1                             Steak Bowl
# 92   93        40         1                     Steak Crispy Tacos
# 93   94        41         1                       Carnitas Burrito
# 94   95        41         1                    Chips and Guacamole
# 95   96        42         1                          Barbacoa Bowl
# 96   97        42         1                    Chips and Guacamole
# 97   98        43         1                          Carnitas Bowl
# 98   99        43         1                        Chicken Burrito
# 99  100        44         1                           Chicken Bowl
#
#                                                                            choice_description  \
# 0                                                                                         nan
# 1                                                                                [Clementine]
# 2                                                                                     [Apple]
# 3                                                                                         nan
# 4                  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 5                 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 6                                                                                         nan
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour...
# 8                   [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 9         [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 10                                                                                        nan
# 11     [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
# 12                        [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 13             [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]
# 14                                                                                        nan
# 15                                                                                        nan
# 16                  [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]
# 17              [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 18                                                                                   [Sprite]
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettu...
# 20                                                                                        nan
# 21  [[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili...
# 22                                                                       [Pomegranate Cherry]
# 23  [[Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Pinto Beans...
# 24                                                                               [Grapefruit]
# 25                                                                                        nan
# 26  [Roasted Chili Corn Salsa (Medium), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 27  [[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Bea...
# 28                                                                               [Dr. Pepper]
# 29            [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Rice, Cheese, Sour Cream]]
# 30                                                                                        nan
# 31  [[Roasted Chili Corn Salsa (Medium), Fresh Tomato Salsa (Mild)], [Rice, Black Beans, S...
# 32                                                                                        nan
# 33  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cre...
# 34                                                                                        nan
# 35                                                           [Roasted Chili Corn Salsa, Rice]
# 36                                              [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# 37                                                                                        nan
# 38                                                                                        nan
# 39  [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, ...
# 40                                                                                        nan
# 41                                                                                        nan
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 43          [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 44                            [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
# 45  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Gu...
# 46                          [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajita Veggies, Cheese]]
# 47                                                                               [Blackberry]
# 48  [[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Sa...
# 49                                                                                        nan
# 50   [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]
# 51                                                                             [Mountain Dew]
# 52  [Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 53                                                                                   [Sprite]
# 54       [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cream]]
# 55                                                                                        nan
# 56                            [Fresh Tomato Salsa, [Fajita Vegetables, Black Beans, Lettuce]]
# 57  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream,...
# 58  [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, ...
# 59                                                                                        nan
# 60                                                                                        nan
# 61                                                               [Fresh Tomato Salsa, Cheese]
# 62  [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacam...
# 63                                          [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# 64  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Fajita Veggies, Cheese, Sour Cre...
# 65                     [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]
# 66                                                                               [Blackberry]
# 67                                          [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]
# 68  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Fajita Veggies, Cheese, Sour Cream, Gu...
# 69                       [Roasted Chili Corn Salsa (Medium), [Rice, Black Beans, Sour Cream]]
# 70                                                                                        nan
# 71        [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 72                                                                                        nan
# 73                       [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 74                                                                                        nan
# 75                           [Tomatillo Red Chili Salsa, [Rice, Cheese, Sour Cream, Lettuce]]
# 76                    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Lettuce]]
# 77                                                                                        nan
# 78                     [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 79                             [Roasted Chili Corn Salsa, [Rice, Cheese, Lettuce, Guacamole]]
# 80                                                                                        nan
# 81                     [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 82                     [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 83                     [Tomatillo Green Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese]]
# 84                                                                [Tomatillo Red Chili Salsa]
# 85  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Black Beans, Rice, Fajita Veggies, Let...
# 86    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans, Rice, Fajita Veggies, Cheese, Lettuce]]
# 87                                                                                        nan
# 88                              [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour Cream, Cheese]]
# 89                                                                                        nan
# 90                   [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole]]
# 91                   [Fresh Tomato Salsa, [Fajita Vegetables, Cheese, Sour Cream, Guacamole]]
# 92                                                           [Fresh Tomato Salsa, Sour Cream]
# 93                                        [Roasted Chili Corn Salsa, [Sour Cream, Guacamole]]
# 94                                                                                        nan
# 95                        [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream]]
# 96                                                                                        nan
# 97   [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Guacamole, Lettuce]]
# 98                                   [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese]]
# 99                [Tomatillo Red Chili Salsa, [Rice, Fajita Vegetables, Sour Cream, Lettuce]]
#
#    item_price
# 0      $2.39
# 1      $3.39
# 2      $3.39
# 3      $2.39
# 4     $16.98
# 5     $10.98
# 6      $1.69
# 7     $11.75
# 8      $9.25
# 9      $9.25
# 10     $4.45
# 11     $8.75
# 12     $8.75
# 13    $11.25
# 14     $4.45
# 15     $2.39
# 16     $8.49
# 17     $8.49
# 18     $2.18
# 19     $8.75
# 20     $4.45
# 21     $8.99
# 22     $3.39
# 23    $10.98
# 24     $3.39
# 25     $2.39
# 26     $8.49
# 27     $8.99
# 28     $1.09
# 29     $8.49
# 30     $2.39
# 31     $8.99
# 32     $1.69
# 33     $8.99
# 34     $1.09
# 35     $8.75
# 36     $8.75
# 37     $4.45
# 38     $2.95
# 39    $11.75
# 40     $2.15
# 41     $4.45
# 42    $11.25
# 43    $11.75
# 44     $8.75
# 45    $10.98
# 46     $8.99
# 47     $3.39
# 48     $8.99
# 49     $3.99
# 50     $8.99
# 51     $2.18
# 52    $10.98
# 53     $1.09
# 54     $8.99
# 55     $2.39
# 56     $9.25
# 57    $11.25
# 58    $11.75
# 59     $2.15
# 60     $4.45
# 61     $9.25
# 62    $11.25
# 63     $8.75
# 64     $8.99
# 65     $8.99
# 66     $3.39
# 67     $8.99
# 68    $10.98
# 69     $8.99
# 70     $1.69
# 71     $8.99
# 72     $3.99
# 73     $8.75
# 74     $4.45
# 75     $8.75
# 76     $8.75
# 77     $2.15
# 78     $8.75
# 79    $11.25
# 80     $2.15
# 81     $9.25
# 82     $8.75
# 83     $8.75
# 84     $9.25
# 85     $8.49
# 86     $8.99
# 87     $1.09
# 88     $9.25
# 89     $2.95
# 90    $11.75
# 91    $11.75
# 92     $9.25
# 93    $11.75
# 94     $4.45
# 95     $9.25
# 96     $4.45
# 97    $11.75
# 98     $8.75
# 99     $8.75

# %%
cl.shape
# Out:
# (100, 6)

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  100 non-null    int64
#  1   order_id            100 non-null    int64
#  2   quantity            100 non-null    int64
#  3   item_name           100 non-null    object
#  4   choice_description  100 non-null    object
#  5   item_price          100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
cl['item_price'] = cl.item_price.str.replace('$',"").astype('float')
# Out:
# /var/folders/lt/mq77_h29005b8q_dkwt9pz000000gn/T/ipykernel_35300/3016442378.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cl['item_price'] = cl.item_price.str.replace('$',"").astype('float')

# %% [markdown]
# What is the total price for each order?

# %%
cl.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1     11.56
# 2     16.98
# 3     12.67
# 4     21.00
# 5     13.70
# 6     17.50
# 7     15.70
# 8     10.88
# 9     10.67
# 10    13.20
# 11    12.38
# 12    14.37
# 13    10.88
# 14    10.08
# 15    10.88
# 16    10.68
# 17    10.08
# 18    24.90
# 19    13.90
# 20    36.20
# 21    23.36
# 22    12.98
# 23    11.17
# 24    12.07
# 25    11.38
# 26    20.50
# 27    13.90
# 28    33.70
# 29    17.98
# 30    23.36
# 31    10.68
# 32    12.98
# 33    13.20
# 34    28.40
# 35    13.40
# 36    18.00
# 37    18.00
# 38    18.57
# 39    12.20
# 40    32.75
# 41    16.20
# 42    13.70
# 43    20.50
# 44     8.75
# Name: item_price, dtype: float64

# %% [markdown]
# What are the most popular 3 items?

# %%
top_three = cl.groupby('item_name').quantity.sum().sort_values(ascending=False).nlargest(n = 3)

# %%
top_three
# Out:
# item_name
# Chicken Burrito        12
# Chips and Guacamole    11
# Steak Burrito          11
# Name: quantity, dtype: int64

# %% [markdown]
# You can visualize in matplotlib

# %% [markdown]
# Which item has produced the most revenue?

# %%
most_revenue = cl.groupby('item_name').item_price.sum().sort_values(ascending = False).head(1)
most_revenue
# Out:
# item_name
# Chicken Burrito    113.14
# Name: item_price, dtype: float64

# %% [markdown]
# Join the employees and titles DataFrames together

# %%
pd.merge

# %% [markdown]
# For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employee_titles.groupby('title')[['hire_date']].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lt/mq77_h29005b8q_dkwt9pz000000gn/T/ipykernel_35300/1945790574.py in <module>
# ----> 1 employee_titles.groupby('title')[['hire_date']].max()
#
# NameError: name 'employee_titles' is not defined

# %% [markdown]
# Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
query = ''''''
SELECT emp_no, title, dept_name 

FROM employees
JOIN titles USING(emp_no)
JOIN dept_emp USING(emp_no)
JOIN departments USING(dept_no)

where titles.to_date = "9999-01-01"
and dept_emp.to_date = "9999-01-01"

# %%
Three Methods

# %% [markdown]
# Group by: reshapes your data, in order to look at things in aggregate terms instead of individual terms.
# Group by is very important in the business world.
# Topics of technical interview: joins and groupby
#
# pd.crosstab
# pd.crosstab(df.passing_math, df.classroom)
# pd.crosstab(index, columns)
# This is a count of people who are failing and people who are passing
# if you need a summation of the entire row you add 'margins=True'
# dropna=True --- this is to get the system to ignore missing values
# pd.crosstab(index, columns)
#
# pivot tables
#
# df.pivot_table(index='day', columns="time", values="tip", aggfunc="median")

# %%
Notes
